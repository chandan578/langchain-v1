# %% [markdown]
# ### Middleware
#
# Middleware provides a way to more tightly control what happens inside the agent. Middleware is useful for the following:
# - Tracking agent behavior with logging, analytics, and debugging.
# - Transforming prompts, tool selection, and output formatting.
# - Adding retries, fallbacks, and early termination logic.
# - Applying rate limits, guardrails, and PII detection.

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['GROQ_API_KEY'] = os.getenv('GROQ_API_KEY')

# %% [markdown]
# ### Summarization MiddleWare
# Automatically summarize conversation history when approaching token limits, preserving recent messages while compressing older context. Summarization is useful for the following:
# - Long-running conversations that exceed context windows.
# - Multi-turn dialogues with extensive history.
# - Applications where preserving full conversation context matters.

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langchain_core.messages import SystemMessage, AIMessage, HumanMessage
from langgraph.checkpoint.memory import InMemorySaver
from langchain_groq import ChatGroq

## message summarization
llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0
)

agent = create_agent(
    model=llm,
    checkpointer=InMemorySaver(),
    middleware=[
        SummarizationMiddleware(
            model=llm,
            trigger=('messages', 10),
            keep=('messages', 4)
        )
    ]
)
# Out:
# c:\Coding\AI_ML_DL\genAI-with-langchain\langchain-antigravity\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
## Run with thread id

config = {'configurable': {'thread_id': 'test-1'}}

# %%
## alternative test data

questions = [
    'What is 2+2?',
    'What is 100/5?',
    'What is 100*5?',
    'What is 100-5?',
    'What is 5*5?',
    'What is 10^4?',
]

for q in questions:
    response = agent.invoke({'messages': [HumanMessage(content=q)]}, config=config)
    print(f"message: {response}")
    print(f"message length : {len(response['messages'])}" )
# Out:
# message: {'messages': [HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={}, id='a6b9c8c9-1d93-42c2-aaab-f64905fec8f2'), AIMessage(content='2 + 2 = 4.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 42, 'total_tokens': 51, 'completion_time': 0.006546495, 'completion_tokens_details': None, 'prompt_time': 0.001970839, 'prompt_tokens_details': None, 'queue_time': 0.053195539, 'total_time': 0.008517334}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-ebf1-7c40-8273-f0ffcedc3960-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 9, 'total_tokens': 51})]}
# message length : 2
# message: {'messages': [HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={}, id='a6b9c8c9-1d93-42c2-aaab-f64905fec8f2'), AIMessage(content='2 + 2 = 4.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 42, 'total_tokens': 51, 'completion_time': 0.006546495, 'completion_tokens_details': None, 'prompt_time': 0.001970839, 'prompt_tokens_details': None, 'queue_time': 0.053195539, 'total_time': 0.008517334}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-ebf1-7c40-8273-f0ffcedc3960-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 9, 'total_tokens': 51}), HumanMessage(content='What is 100/5?', additional_kwargs={}, response_metadata={}, id='884e5da4-c20f-4b05-885e-1388b5e09343'), AIMessage(content='100 / 5 = 20.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 67, 'total_tokens': 76, 'completion_time': 0.009734788, 'completion_tokens_details': None, 'prompt_time': 0.003698875, 'prompt_tokens_details': None, 'queue_time': 0.054798975, 'total_time': 0.013433663}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_ff2b098aaf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-ecf5-7601-8731-4f6333624fa4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 67, 'output_tokens': 9, 'total_tokens': 76})]}
# message length : 4
# message: {'messages': [HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={}, id='a6b9c8c9-1d93-42c2-aaab-f64905fec8f2'), AIMessage(content='2 + 2 = 4.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 42, 'total_tokens': 51, 'completion_time': 0.006546495, 'completion_tokens_details': None, 'prompt_time': 0.001970839, 'prompt_tokens_details': None, 'queue_time': 0.053195539, 'total_time': 0.008517334}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-ebf1-7c40-8273-f0ffcedc3960-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 9, 'total_tokens': 51}), HumanMessage(content='What is 100/5?', additional_kwargs={}, response_metadata={}, id='884e5da4-c20f-4b05-885e-1388b5e09343'), AIMessage(content='100 / 5 = 20.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 67, 'total_tokens': 76, 'completion_time': 0.009734788, 'completion_tokens_details': None, 'prompt_time': 0.003698875, 'prompt_tokens_details': None, 'queue_time': 0.054798975, 'total_time': 0.013433663}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_ff2b098aaf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-ecf5-7601-8731-4f6333624fa4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 67, 'output_tokens': 9, 'total_tokens': 76}), HumanMessage(content='What is 100*5?', additional_kwargs={}, response_metadata={}, id='ccdbf60f-f270-450e-ab8e-9b46cf187a6b'), AIMessage(content='100 * 5 = 500.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 92, 'total_tokens': 101, 'completion_time': 0.005279631, 'completion_tokens_details': None, 'prompt_time': 0.005069495, 'prompt_tokens_details': None, 'queue_time': 0.054586805, 'total_time': 0.010349126}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-ed67-7b81-bf73-a1ce2ec0c952-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 92, 'output_tokens': 9, 'total_tokens': 101})]}
# message length : 6
# message: {'messages': [HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={}, id='a6b9c8c9-1d93-42c2-aaab-f64905fec8f2'), AIMessage(content='2 + 2 = 4.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 42, 'total_tokens': 51, 'completion_time': 0.006546495, 'completion_tokens_details': None, 'prompt_time': 0.001970839, 'prompt_tokens_details': None, 'queue_time': 0.053195539, 'total_time': 0.008517334}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-ebf1-7c40-8273-f0ffcedc3960-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 9, 'total_tokens': 51}), HumanMessage(content='What is 100/5?', additional_kwargs={}, response_metadata={}, id='884e5da4-c20f-4b05-885e-1388b5e09343'), AIMessage(content='100 / 5 = 20.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 67, 'total_tokens': 76, 'completion_time': 0.009734788, 'completion_tokens_details': None, 'prompt_time': 0.003698875, 'prompt_tokens_details': None, 'queue_time': 0.054798975, 'total_time': 0.013433663}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_ff2b098aaf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-ecf5-7601-8731-4f6333624fa4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 67, 'output_tokens': 9, 'total_tokens': 76}), HumanMessage(content='What is 100*5?', additional_kwargs={}, response_metadata={}, id='ccdbf60f-f270-450e-ab8e-9b46cf187a6b'), AIMessage(content='100 * 5 = 500.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 92, 'total_tokens': 101, 'completion_time': 0.005279631, 'completion_tokens_details': None, 'prompt_time': 0.005069495, 'prompt_tokens_details': None, 'queue_time': 0.054586805, 'total_time': 0.010349126}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-ed67-7b81-bf73-a1ce2ec0c952-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 92, 'output_tokens': 9, 'total_tokens': 101}), HumanMessage(content='What is 100-5?', additional_kwargs={}, response_metadata={}, id='9ef5c940-9b62-4efe-ba13-cffad229821f'), AIMessage(content='100 - 5 = 95.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 117, 'total_tokens': 126, 'completion_time': 0.00504795, 'completion_tokens_details': None, 'prompt_time': 0.006459417, 'prompt_tokens_details': None, 'queue_time': 0.050417733, 'total_time': 0.011507367}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-edcf-7af3-afb5-d3639d96f829-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 117, 'output_tokens': 9, 'total_tokens': 126})]}
# message length : 8
# message: {'messages': [HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={}, id='a6b9c8c9-1d93-42c2-aaab-f64905fec8f2'), AIMessage(content='2 + 2 = 4.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 42, 'total_tokens': 51, 'completion_time': 0.006546495, 'completion_tokens_details': None, 'prompt_time': 0.001970839, 'prompt_tokens_details': None, 'queue_time': 0.053195539, 'total_time': 0.008517334}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-ebf1-7c40-8273-f0ffcedc3960-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 9, 'total_tokens': 51}), HumanMessage(content='What is 100/5?', additional_kwargs={}, response_metadata={}, id='884e5da4-c20f-4b05-885e-1388b5e09343'), AIMessage(content='100 / 5 = 20.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 67, 'total_tokens': 76, 'completion_time': 0.009734788, 'completion_tokens_details': None, 'prompt_time': 0.003698875, 'prompt_tokens_details': None, 'queue_time': 0.054798975, 'total_time': 0.013433663}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_ff2b098aaf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-ecf5-7601-8731-4f6333624fa4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 67, 'output_tokens': 9, 'total_tokens': 76}), HumanMessage(content='What is 100*5?', additional_kwargs={}, response_metadata={}, id='ccdbf60f-f270-450e-ab8e-9b46cf187a6b'), AIMessage(content='100 * 5 = 500.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 92, 'total_tokens': 101, 'completion_time': 0.005279631, 'completion_tokens_details': None, 'prompt_time': 0.005069495, 'prompt_tokens_details': None, 'queue_time': 0.054586805, 'total_time': 0.010349126}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-ed67-7b81-bf73-a1ce2ec0c952-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 92, 'output_tokens': 9, 'total_tokens': 101}), HumanMessage(content='What is 100-5?', additional_kwargs={}, response_metadata={}, id='9ef5c940-9b62-4efe-ba13-cffad229821f'), AIMessage(content='100 - 5 = 95.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 117, 'total_tokens': 126, 'completion_time': 0.00504795, 'completion_tokens_details': None, 'prompt_time': 0.006459417, 'prompt_tokens_details': None, 'queue_time': 0.050417733, 'total_time': 0.011507367}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-edcf-7af3-afb5-d3639d96f829-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 117, 'output_tokens': 9, 'total_tokens': 126}), HumanMessage(content='What is 5*5?', additional_kwargs={}, response_metadata={}, id='f1a14eeb-b2c3-44c1-81de-048b33ccb4ab'), AIMessage(content='5 * 5 = 25.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 142, 'total_tokens': 151, 'completion_time': 0.004751594, 'completion_tokens_details': None, 'prompt_time': 0.007849675, 'prompt_tokens_details': None, 'queue_time': 0.053268815, 'total_time': 0.012601269}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-ee32-7092-905e-a828a9290c40-0', tool_calls=[], invalid_tool_calls=[], usage_ ...
# message length : 10
# message: {'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\n2 + 2 = 4, 100 / 5 = 20, 100 * 5 = 500, 100 - 5 = ?', additional_kwargs={}, response_metadata={}, id='52810e1a-a39a-4df7-a2e2-c1bcfedc5165'), AIMessage(content='100 - 5 = 95.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 117, 'total_tokens': 126, 'completion_time': 0.00504795, 'completion_tokens_details': None, 'prompt_time': 0.006459417, 'prompt_tokens_details': None, 'queue_time': 0.050417733, 'total_time': 0.011507367}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-edcf-7af3-afb5-d3639d96f829-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 117, 'output_tokens': 9, 'total_tokens': 126}), HumanMessage(content='What is 5*5?', additional_kwargs={}, response_metadata={}, id='f1a14eeb-b2c3-44c1-81de-048b33ccb4ab'), AIMessage(content='5 * 5 = 25.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 142, 'total_tokens': 151, 'completion_time': 0.004751594, 'completion_tokens_details': None, 'prompt_time': 0.007849675, 'prompt_tokens_details': None, 'queue_time': 0.053268815, 'total_time': 0.012601269}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-ee32-7092-905e-a828a9290c40-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 142, 'output_tokens': 9, 'total_tokens': 151}), HumanMessage(content='What is 10^4?', additional_kwargs={}, response_metadata={}, id='ab05707b-0101-4f1d-9b3f-785ea34771b4'), AIMessage(content='10^4 is equal to 10 multiplied by itself 4 times, which is 10,000.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 128, 'total_tokens': 151, 'completion_time': 0.025297984, 'completion_tokens_details': None, 'prompt_time': 0.007019647, 'prompt_tokens_details': None, 'queue_time': 0.054717054, 'total_time': 0.032317631}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_ff2b098aaf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-ef3a-7200-8cf3-b894888af60b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 128, 'output_tokens': 23, 'total_tokens': 151})]}
# message length : 6

# %% [markdown]
# ##### Token size summerization

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langgraph.checkpoint.memory import InMemorySaver
from langchain_core.messages import SystemMessage, AIMessage
from langchain_groq import ChatGroq
from langchain_core.tools import tool

@tool
def search_hotels(city: str) -> str:
    """Search hotels - returns long response to use more tokens."""
    return f"""Hotels in {city}:
    1. Grand Hotel - 5 star, $350/night, spa, pool, gym
    2. City Inn - 4 star, $180/night, business center
    3. Budget Stay - 3 star, $75/night, free wifi"""

agent = create_agent(
    model=llm,
    tools= [search_hotels],
    checkpointer=InMemorySaver(),
    middleware=[
        SummarizationMiddleware(
            model=llm,
            trigger=('tokens', 500),
            keep=('tokens', 100)
        )
    ]
)

# %%
config = {"configurable": {"thread_id": "test-1"}}

# %%
## token counter
def count_tokens(message):
    total_chars = sum(len(str(m.content)) for m in message)
    return total_chars //4

# %%
cities = ['New Delhi', 'Mumbai', 'Bangalore', 'Hyderabad', 'Chennai']

for city in cities:
    response = agent.invoke({
        'messages': [HumanMessage(content=f'Find the best hotel in {city}')]
    }, config=config)

    tokens = count_tokens(response['messages'])
    print(f"{city}: ~{tokens} tokens, {len(response['messages'])} messages")
    print(f"{response['messages']}")
# Out:
# New Delhi: ~74 tokens, 4 messages
# [HumanMessage(content='Find the best hotel in New Delhi', additional_kwargs={}, response_metadata={}, id='a3c67b6e-474c-4c46-9933-7a9741e88264'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '6s4x3hzys', 'function': {'arguments': '{"city":"New Delhi"}', 'name': 'search_hotels'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 229, 'total_tokens': 245, 'completion_time': 0.014360783, 'completion_tokens_details': None, 'prompt_time': 0.012785234, 'prompt_tokens_details': None, 'queue_time': 0.053748356, 'total_time': 0.027146017}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-efed-79a1-8027-9a8ed264b613-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'New Delhi'}, 'id': '6s4x3hzys', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 229, 'output_tokens': 16, 'total_tokens': 245}), ToolMessage(content='Hotels in New Delhi:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='9a6034f4-c169-44ce-b8f7-628881b85884', tool_call_id='6s4x3hzys'), AIMessage(content='The response provided is a fictional example and may not reflect real-world results.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 320, 'total_tokens': 336, 'completion_time': 0.043931611, 'completion_tokens_details': None, 'prompt_time': 0.017965721, 'prompt_tokens_details': None, 'queue_time': 0.050753279, 'total_time': 0.061897332}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-f06d-7190-9bfc-772fc4d25e39-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 320, 'output_tokens': 16, 'total_tokens': 336})]
# Mumbai: ~146 tokens, 8 messages
# [HumanMessage(content='Find the best hotel in New Delhi', additional_kwargs={}, response_metadata={}, id='a3c67b6e-474c-4c46-9933-7a9741e88264'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '6s4x3hzys', 'function': {'arguments': '{"city":"New Delhi"}', 'name': 'search_hotels'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 229, 'total_tokens': 245, 'completion_time': 0.014360783, 'completion_tokens_details': None, 'prompt_time': 0.012785234, 'prompt_tokens_details': None, 'queue_time': 0.053748356, 'total_time': 0.027146017}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-efed-79a1-8027-9a8ed264b613-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'New Delhi'}, 'id': '6s4x3hzys', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 229, 'output_tokens': 16, 'total_tokens': 245}), ToolMessage(content='Hotels in New Delhi:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='9a6034f4-c169-44ce-b8f7-628881b85884', tool_call_id='6s4x3hzys'), AIMessage(content='The response provided is a fictional example and may not reflect real-world results.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 320, 'total_tokens': 336, 'completion_time': 0.043931611, 'completion_tokens_details': None, 'prompt_time': 0.017965721, 'prompt_tokens_details': None, 'queue_time': 0.050753279, 'total_time': 0.061897332}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-f06d-7190-9bfc-772fc4d25e39-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 320, 'output_tokens': 16, 'total_tokens': 336}), HumanMessage(content='Find the best hotel in Mumbai', additional_kwargs={}, response_metadata={}, id='e6efe83d-6a77-4b8f-b5eb-e099fc30b837'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'k6tqt4pxa', 'function': {'arguments': '{"city":"Mumbai"}', 'name': 'search_hotels'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 351, 'total_tokens': 367, 'completion_time': 0.010324684, 'completion_tokens_details': None, 'prompt_time': 0.019590958, 'prompt_tokens_details': None, 'queue_time': 0.053543921, 'total_time': 0.029915642}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-f10a-72e1-9ded-bcf8972e99ec-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Mumbai'}, 'id': 'k6tqt4pxa', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 351, 'output_tokens': 16, 'total_tokens': 367}), ToolMessage(content='Hotels in Mumbai:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='152228f5-c7cd-4463-93d4-ef0216726fd5', tool_call_id='k6tqt4pxa'), AIMessage(content='The response provided is a fictional example and may not reflect real-world results.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 441, 'total_tokens': 457, 'completion_time': 0.01650237, 'completion_tokens_details': None, 'prompt_time': 0.026562459, 'prompt_tokens_details': None, 'queue_time': 0.054337201, 'total_time': 0.043064829}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'lo ...
# Bangalore: ~220 tokens, 12 messages
# [HumanMessage(content='Find the best hotel in New Delhi', additional_kwargs={}, response_metadata={}, id='a3c67b6e-474c-4c46-9933-7a9741e88264'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '6s4x3hzys', 'function': {'arguments': '{"city":"New Delhi"}', 'name': 'search_hotels'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 229, 'total_tokens': 245, 'completion_time': 0.014360783, 'completion_tokens_details': None, 'prompt_time': 0.012785234, 'prompt_tokens_details': None, 'queue_time': 0.053748356, 'total_time': 0.027146017}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-efed-79a1-8027-9a8ed264b613-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'New Delhi'}, 'id': '6s4x3hzys', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 229, 'output_tokens': 16, 'total_tokens': 245}), ToolMessage(content='Hotels in New Delhi:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='9a6034f4-c169-44ce-b8f7-628881b85884', tool_call_id='6s4x3hzys'), AIMessage(content='The response provided is a fictional example and may not reflect real-world results.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 320, 'total_tokens': 336, 'completion_time': 0.043931611, 'completion_tokens_details': None, 'prompt_time': 0.017965721, 'prompt_tokens_details': None, 'queue_time': 0.050753279, 'total_time': 0.061897332}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-f06d-7190-9bfc-772fc4d25e39-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 320, 'output_tokens': 16, 'total_tokens': 336}), HumanMessage(content='Find the best hotel in Mumbai', additional_kwargs={}, response_metadata={}, id='e6efe83d-6a77-4b8f-b5eb-e099fc30b837'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'k6tqt4pxa', 'function': {'arguments': '{"city":"Mumbai"}', 'name': 'search_hotels'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 351, 'total_tokens': 367, 'completion_time': 0.010324684, 'completion_tokens_details': None, 'prompt_time': 0.019590958, 'prompt_tokens_details': None, 'queue_time': 0.053543921, 'total_time': 0.029915642}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-f10a-72e1-9ded-bcf8972e99ec-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Mumbai'}, 'id': 'k6tqt4pxa', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 351, 'output_tokens': 16, 'total_tokens': 367}), ToolMessage(content='Hotels in Mumbai:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='152228f5-c7cd-4463-93d4-ef0216726fd5', tool_call_id='k6tqt4pxa'), AIMessage(content='The response provided is a fictional example and may not reflect real-world results.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 441, 'total_tokens': 457, 'completion_time': 0.01650237, 'completion_tokens_details': None, 'prompt_time': 0.026562459, 'prompt_tokens_details': None, 'queue_time': 0.054337201, 'total_time': 0.043064829}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'lo ...
# Hyderabad: ~266 tokens, 8 messages
# [HumanMessage(content='Here is a summary of the conversation to date:\n\nThe user is searching for hotels in three cities: New Delhi, Mumbai, and Bangalore. They are looking for the best hotel in each city. The user has already received a list of hotels in New Delhi and Mumbai, but not in Bangalore. \n\nThe user is interested in hotels with the following features: \n- Grand Hotel (5 star)\n- Spa\n- Pool\n- Gym\n- Business center\n- Free wifi\n\nThe user is also interested in the price of the hotels, with a budget of at least $75/night.', additional_kwargs={}, response_metadata={}, id='4c1c8e19-b708-48bd-8a95-905d092c3948'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'j4qx9nyec', 'function': {'arguments': '{"city":"Bangalore"}', 'name': 'search_hotels'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 472, 'total_tokens': 488, 'completion_time': 0.010568459, 'completion_tokens_details': None, 'prompt_time': 0.030935021, 'prompt_tokens_details': None, 'queue_time': 0.054545617, 'total_time': 0.04150348}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-f215-7b92-939e-12e1b0a5d814-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Bangalore'}, 'id': 'j4qx9nyec', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 472, 'output_tokens': 16, 'total_tokens': 488}), ToolMessage(content='Hotels in Bangalore:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='0c2404c9-10a6-4191-baa0-55bbecf95017', tool_call_id='j4qx9nyec'), AIMessage(content='The response provided is a fictional example and may not reflect real-world results.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 562, 'total_tokens': 578, 'completion_time': 0.011201255, 'completion_tokens_details': None, 'prompt_time': 0.031151657, 'prompt_tokens_details': None, 'queue_time': 0.054078771, 'total_time': 0.042352912}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-f2a4-7dc1-817c-fc62a203e920-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 562, 'output_tokens': 16, 'total_tokens': 578}), HumanMessage(content='Find the best hotel in Hyderabad', additional_kwargs={}, response_metadata={}, id='a5ccac15-e545-4434-8e10-cc598aed241a'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'zj31tzf6n', 'function': {'arguments': '{"city":"Hyderabad"}', 'name': 'search_hotels'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 462, 'total_tokens': 478, 'completion_time': 0.010476575, 'completion_tokens_details': None, 'prompt_time': 0.027017019, 'prompt_tokens_details': None, 'queue_time': 0.048927261, 'total_time': 0.037493594}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-f487-7813-a063-97aa374dcb35-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Hyderabad'}, 'id': 'zj31tzf6n', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 462, 'output_tokens': 16, 'total_tokens': 478}), ToolMessage(content='Hotels in Hyderabad:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='bfa46bcc-3b66-46b6-986c-3d1b87c8bc17', tool_call_id='zj31tzf6n'), AIMessage(content='The response provided is a fi ...
# Chennai: ~229 tokens, 5 messages
# [HumanMessage(content='Here is a summary of the conversation to date:\n\nThe user is searching for hotels in three cities: New Delhi, Mumbai, and Bangalore. They are looking for the best hotel in each city with the following features: \n- Grand Hotel (5 star)\n- Spa\n- Pool\n- Gym\n- Business center\n- Free wifi\n\nThe user has a budget of at least $75/night. \n\nThe user has already received a list of hotels in New Delhi and Mumbai, but not in Bangalore. The list of hotels in Bangalore includes:\n1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n2. City Inn - 4 star, $180/night, business center\n3. Budget Stay - 3 star, $75/night, free wifi', additional_kwargs={}, response_metadata={}, id='e403c199-bae4-4727-9e29-a968dda5688e'), HumanMessage(content='Find the best hotel in Chennai', additional_kwargs={}, response_metadata={}, id='c33c8eb0-d9cd-4e42-a473-bc02ea18c08e'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '364s41j2n', 'function': {'arguments': '{"city":"Chennai"}', 'name': 'search_hotels'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 531, 'total_tokens': 547, 'completion_time': 0.012419042, 'completion_tokens_details': None, 'prompt_time': 0.03050748, 'prompt_tokens_details': None, 'queue_time': 0.054054919, 'total_time': 0.042926522}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1797-f6c6-7f13-9b55-0523da395169-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Chennai'}, 'id': '364s41j2n', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 531, 'output_tokens': 16, 'total_tokens': 547}), ToolMessage(content='Hotels in Chennai:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='1493b59c-b526-4f16-bfaa-bc86e1147fe7', tool_call_id='364s41j2n'), AIMessage(content='The best hotel in Chennai is the Grand Hotel, which is a 5-star hotel with a spa, pool, and gym.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 486, 'total_tokens': 513, 'completion_time': 0.065752865, 'completion_tokens_details': None, 'prompt_time': 0.032521393, 'prompt_tokens_details': None, 'queue_time': 0.054054896, 'total_time': 0.098274258}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1798-23d6-7802-9d91-18dec806ca09-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 486, 'output_tokens': 27, 'total_tokens': 513})]

# %% [markdown]
# #### Based on Fraction

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
from langgraph.checkpoint.memory import InMemorySaver
from langchain_groq import ChatGroq

@tool
def search_hotels(city: str) -> str:
    """Search for hotels in a given city."""
    return f"Searching for hotels in {city}: Grand Hotel 2000, Luxury Hotel 1000, normal hotel 500"

llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0,
)

## low fraction for testing
agent = create_agent(
    model=llm,
    tools=[search_hotels,],
    checkpointer= InMemorySaver(),
    middleware=[
        SummarizationMiddleware(
            model=llm,
            trigger=('fraction', 0.005), ## 0.5% = ~640 tokens
            keep= ('fraction', 0.002)
        )
    ]
)
# config = {"configurable": {"thread_id": "test-1"}}

config = {"configurable": {'thread_id': 'test-1'}}

def count_tokens(messages):
    return sum(len(str(m.content)) for m in messages)

# %%
cities = ['Delhi', 'Mumbai', 'Bangalore', 'Hyderabad', 'Patna']

for city in cities:
    response= agent.invoke(
        {'messages': [HumanMessage(content=f'Hotels in {city}')]},
        config = config
    )

    tokens = count_tokens(response['messages'])
    fraction = tokens / 128000
    print(f'{city}: ~{tokens} tokens ({fraction: .4%}), {len(response["messages"])} msgs')
    print(response['messages'])
# Out:
# Delhi: ~427 tokens ( 0.3336%), 7 msgs
# [HumanMessage(content='Hotels in Delhi', additional_kwargs={}, response_metadata={}, id='5ce267e4-b9d9-4829-a5a6-aceeea6cf88e'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'tjt74dzne', 'function': {'arguments': '{"city":"Delhi"}', 'name': 'search_hotels'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 220, 'total_tokens': 236, 'completion_time': 0.027641021, 'completion_tokens_details': None, 'prompt_time': 0.013714927, 'prompt_tokens_details': None, 'queue_time': 0.053912406, 'total_time': 0.041355948}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1798-3a23-7323-8f56-75c26a99c073-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Delhi'}, 'id': 'tjt74dzne', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 220, 'output_tokens': 16, 'total_tokens': 236}), ToolMessage(content='Searching for hotels in Delhi: Grand Hotel 2000, Luxury Hotel 1000, normal hotel 500', name='search_hotels', id='54877bed-7123-4405-bc6e-1c2517294ac5', tool_call_id='tjt74dzne'), HumanMessage(content='Hotels in Delhi', additional_kwargs={}, response_metadata={}, id='cd5f9576-c418-495c-a9cb-d8c9d661a26b'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'ge7bp2m2p', 'function': {'arguments': '{"city":"Delhi"}', 'name': 'search_hotels'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 277, 'total_tokens': 293, 'completion_time': 0.012667707, 'completion_tokens_details': None, 'prompt_time': 0.02997917, 'prompt_tokens_details': None, 'queue_time': 0.05450561, 'total_time': 0.042646877}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1798-85a5-7031-953e-18974ff4bd4c-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Delhi'}, 'id': 'ge7bp2m2p', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 277, 'output_tokens': 16, 'total_tokens': 293}), ToolMessage(content='Searching for hotels in Delhi: Grand Hotel 2000, Luxury Hotel 1000, normal hotel 500', name='search_hotels', id='0c50d66e-276a-4a01-9626-595a7061f858', tool_call_id='ge7bp2m2p'), AIMessage(content='It seems like the search_hotels function is returning the same results as before. If you want to get different results, you might want to try searching with different parameters, such as a different city or a specific hotel name.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 46, 'prompt_tokens': 325, 'total_tokens': 371, 'completion_time': 0.093950966, 'completion_tokens_details': None, 'prompt_time': 0.020582322, 'prompt_tokens_details': None, 'queue_time': 0.050411731, 'total_time': 0.114533288}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1798-864a-7593-826b-92dda96f7631-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 325, 'output_tokens': 46, 'total_tokens': 371})]
# Mumbai: ~757 tokens ( 0.5914%), 11 msgs
# [HumanMessage(content='Hotels in Delhi', additional_kwargs={}, response_metadata={}, id='5ce267e4-b9d9-4829-a5a6-aceeea6cf88e'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'tjt74dzne', 'function': {'arguments': '{"city":"Delhi"}', 'name': 'search_hotels'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 220, 'total_tokens': 236, 'completion_time': 0.027641021, 'completion_tokens_details': None, 'prompt_time': 0.013714927, 'prompt_tokens_details': None, 'queue_time': 0.053912406, 'total_time': 0.041355948}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1798-3a23-7323-8f56-75c26a99c073-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Delhi'}, 'id': 'tjt74dzne', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 220, 'output_tokens': 16, 'total_tokens': 236}), ToolMessage(content='Searching for hotels in Delhi: Grand Hotel 2000, Luxury Hotel 1000, normal hotel 500', name='search_hotels', id='54877bed-7123-4405-bc6e-1c2517294ac5', tool_call_id='tjt74dzne'), HumanMessage(content='Hotels in Delhi', additional_kwargs={}, response_metadata={}, id='cd5f9576-c418-495c-a9cb-d8c9d661a26b'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'ge7bp2m2p', 'function': {'arguments': '{"city":"Delhi"}', 'name': 'search_hotels'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 277, 'total_tokens': 293, 'completion_time': 0.012667707, 'completion_tokens_details': None, 'prompt_time': 0.02997917, 'prompt_tokens_details': None, 'queue_time': 0.05450561, 'total_time': 0.042646877}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1798-85a5-7031-953e-18974ff4bd4c-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Delhi'}, 'id': 'ge7bp2m2p', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 277, 'output_tokens': 16, 'total_tokens': 293}), ToolMessage(content='Searching for hotels in Delhi: Grand Hotel 2000, Luxury Hotel 1000, normal hotel 500', name='search_hotels', id='0c50d66e-276a-4a01-9626-595a7061f858', tool_call_id='ge7bp2m2p'), AIMessage(content='It seems like the search_hotels function is returning the same results as before. If you want to get different results, you might want to try searching with different parameters, such as a different city or a specific hotel name.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 46, 'prompt_tokens': 325, 'total_tokens': 371, 'completion_time': 0.093950966, 'completion_tokens_details': None, 'prompt_time': 0.020582322, 'prompt_tokens_details': None, 'queue_time': 0.050411731, 'total_time': 0.114533288}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1798-864a-7593-826b-92dda96f7631-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 325, 'output_tokens': 46, 'total_tokens': 371}), HumanMessage(content='Hotels in Mumbai', additional_kwargs={}, response_metadata={}, id='2c11bd07-8438-4b63-bdaa-a9f901620f38'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '7ym35e557', 'function': {'arguments': '{"city":"Mumbai"}', 'name': 'search_hotels'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 384, 'total_tokens': 400, 'completion_time': 0.010664087, 'completion_tokens_details': None, 'prompt_time': 0.024788054, 'prompt_tokens_details': None, 'queue_time': 0.050474726, 'total_time': 0.035452141}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerp ...
# Bangalore: ~1093 tokens ( 0.8539%), 15 msgs
# [HumanMessage(content='Hotels in Delhi', additional_kwargs={}, response_metadata={}, id='5ce267e4-b9d9-4829-a5a6-aceeea6cf88e'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'tjt74dzne', 'function': {'arguments': '{"city":"Delhi"}', 'name': 'search_hotels'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 220, 'total_tokens': 236, 'completion_time': 0.027641021, 'completion_tokens_details': None, 'prompt_time': 0.013714927, 'prompt_tokens_details': None, 'queue_time': 0.053912406, 'total_time': 0.041355948}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1798-3a23-7323-8f56-75c26a99c073-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Delhi'}, 'id': 'tjt74dzne', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 220, 'output_tokens': 16, 'total_tokens': 236}), ToolMessage(content='Searching for hotels in Delhi: Grand Hotel 2000, Luxury Hotel 1000, normal hotel 500', name='search_hotels', id='54877bed-7123-4405-bc6e-1c2517294ac5', tool_call_id='tjt74dzne'), HumanMessage(content='Hotels in Delhi', additional_kwargs={}, response_metadata={}, id='cd5f9576-c418-495c-a9cb-d8c9d661a26b'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'ge7bp2m2p', 'function': {'arguments': '{"city":"Delhi"}', 'name': 'search_hotels'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 277, 'total_tokens': 293, 'completion_time': 0.012667707, 'completion_tokens_details': None, 'prompt_time': 0.02997917, 'prompt_tokens_details': None, 'queue_time': 0.05450561, 'total_time': 0.042646877}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1798-85a5-7031-953e-18974ff4bd4c-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Delhi'}, 'id': 'ge7bp2m2p', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 277, 'output_tokens': 16, 'total_tokens': 293}), ToolMessage(content='Searching for hotels in Delhi: Grand Hotel 2000, Luxury Hotel 1000, normal hotel 500', name='search_hotels', id='0c50d66e-276a-4a01-9626-595a7061f858', tool_call_id='ge7bp2m2p'), AIMessage(content='It seems like the search_hotels function is returning the same results as before. If you want to get different results, you might want to try searching with different parameters, such as a different city or a specific hotel name.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 46, 'prompt_tokens': 325, 'total_tokens': 371, 'completion_time': 0.093950966, 'completion_tokens_details': None, 'prompt_time': 0.020582322, 'prompt_tokens_details': None, 'queue_time': 0.050411731, 'total_time': 0.114533288}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1798-864a-7593-826b-92dda96f7631-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 325, 'output_tokens': 46, 'total_tokens': 371}), HumanMessage(content='Hotels in Mumbai', additional_kwargs={}, response_metadata={}, id='2c11bd07-8438-4b63-bdaa-a9f901620f38'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '7ym35e557', 'function': {'arguments': '{"city":"Mumbai"}', 'name': 'search_hotels'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 384, 'total_tokens': 400, 'completion_time': 0.010664087, 'completion_tokens_details': None, 'prompt_time': 0.024788054, 'prompt_tokens_details': None, 'queue_time': 0.050474726, 'total_time': 0.035452141}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerp ...
# Hyderabad: ~1429 tokens ( 1.1164%), 19 msgs
# [HumanMessage(content='Hotels in Delhi', additional_kwargs={}, response_metadata={}, id='5ce267e4-b9d9-4829-a5a6-aceeea6cf88e'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'tjt74dzne', 'function': {'arguments': '{"city":"Delhi"}', 'name': 'search_hotels'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 220, 'total_tokens': 236, 'completion_time': 0.027641021, 'completion_tokens_details': None, 'prompt_time': 0.013714927, 'prompt_tokens_details': None, 'queue_time': 0.053912406, 'total_time': 0.041355948}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1798-3a23-7323-8f56-75c26a99c073-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Delhi'}, 'id': 'tjt74dzne', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 220, 'output_tokens': 16, 'total_tokens': 236}), ToolMessage(content='Searching for hotels in Delhi: Grand Hotel 2000, Luxury Hotel 1000, normal hotel 500', name='search_hotels', id='54877bed-7123-4405-bc6e-1c2517294ac5', tool_call_id='tjt74dzne'), HumanMessage(content='Hotels in Delhi', additional_kwargs={}, response_metadata={}, id='cd5f9576-c418-495c-a9cb-d8c9d661a26b'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'ge7bp2m2p', 'function': {'arguments': '{"city":"Delhi"}', 'name': 'search_hotels'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 277, 'total_tokens': 293, 'completion_time': 0.012667707, 'completion_tokens_details': None, 'prompt_time': 0.02997917, 'prompt_tokens_details': None, 'queue_time': 0.05450561, 'total_time': 0.042646877}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1798-85a5-7031-953e-18974ff4bd4c-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Delhi'}, 'id': 'ge7bp2m2p', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 277, 'output_tokens': 16, 'total_tokens': 293}), ToolMessage(content='Searching for hotels in Delhi: Grand Hotel 2000, Luxury Hotel 1000, normal hotel 500', name='search_hotels', id='0c50d66e-276a-4a01-9626-595a7061f858', tool_call_id='ge7bp2m2p'), AIMessage(content='It seems like the search_hotels function is returning the same results as before. If you want to get different results, you might want to try searching with different parameters, such as a different city or a specific hotel name.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 46, 'prompt_tokens': 325, 'total_tokens': 371, 'completion_time': 0.093950966, 'completion_tokens_details': None, 'prompt_time': 0.020582322, 'prompt_tokens_details': None, 'queue_time': 0.050411731, 'total_time': 0.114533288}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1798-864a-7593-826b-92dda96f7631-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 325, 'output_tokens': 46, 'total_tokens': 371}), HumanMessage(content='Hotels in Mumbai', additional_kwargs={}, response_metadata={}, id='2c11bd07-8438-4b63-bdaa-a9f901620f38'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '7ym35e557', 'function': {'arguments': '{"city":"Mumbai"}', 'name': 'search_hotels'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 384, 'total_tokens': 400, 'completion_time': 0.010664087, 'completion_tokens_details': None, 'prompt_time': 0.024788054, 'prompt_tokens_details': None, 'queue_time': 0.050474726, 'total_time': 0.035452141}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerp ...
# Patna: ~1708 tokens ( 1.3344%), 12 msgs
# [HumanMessage(content='Here is a summary of the conversation to date:\n\nThe user is searching for hotels in different cities in India. They initially searched for hotels in Delhi, but the results were the same when they searched again. They then searched for hotels in Mumbai and Bangalore, but the results were the same again. \n\nThe user is likely looking for different hotel options in each city. The search_hotels function is returning the same results for each city, suggesting that the function is not flexible enough to provide different results based on the city or other parameters. \n\nThe user may want to try searching with different parameters, such as a different city or a specific hotel name, to get different results.', additional_kwargs={}, response_metadata={}, id='c9dbbb5a-d6e4-49ec-904e-1806e622d7cd'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'c73x4nrgh', 'function': {'arguments': '{"city":"Bangalore"}', 'name': 'search_hotels'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 491, 'total_tokens': 507, 'completion_time': 0.010341108, 'completion_tokens_details': None, 'prompt_time': 0.02712628, 'prompt_tokens_details': None, 'queue_time': 0.05595804, 'total_time': 0.037467388}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_ff2b098aaf', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1798-884b-73a2-ad8b-9abf90e40276-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Bangalore'}, 'id': 'c73x4nrgh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 491, 'output_tokens': 16, 'total_tokens': 507}), ToolMessage(content='Searching for hotels in Bangalore: Grand Hotel 2000, Luxury Hotel 1000, normal hotel 500', name='search_hotels', id='af38c7d1-e5de-4117-a5fb-18c485433d48', tool_call_id='c73x4nrgh'), AIMessage(content='It seems like the search_hotels function is returning the same results as before. If you want to get different results, you might want to try searching with different parameters, such as a different city or a specific hotel name.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 46, 'prompt_tokens': 539, 'total_tokens': 585, 'completion_time': 0.042864594, 'completion_tokens_details': None, 'prompt_time': 0.036345393, 'prompt_tokens_details': None, 'queue_time': 0.060785827, 'total_time': 0.079209987}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1798-9ca0-7961-aefc-72c0a634308e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 539, 'output_tokens': 46, 'total_tokens': 585}), HumanMessage(content='Hotels in Hyderabad', additional_kwargs={}, response_metadata={}, id='5b666d1c-5fc5-495a-9b4a-b8a4b39953d1'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'qefzaftkv', 'function': {'arguments': '{"city":"Hyderabad"}', 'name': 'search_hotels'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 598, 'total_tokens': 614, 'completion_time': 0.011985403, 'completion_tokens_details': None, 'prompt_time': 0.047221044, 'prompt_tokens_details': None, 'queue_time': 0.059228651, 'total_time': 0.059206447}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1798-b506-75b0-96d1-5ef39b042fe1-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Hyderabad'}, 'id': 'qefzaftkv', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 598, 'output_tokens': 16, 'total_tokens': 614}), ToolMessage(content='Searching for hotels in Hyderabad: Grand Hotel 2000, Luxury Hotel 1000, normal hotel 500', name ...

# %% [markdown]
# ### Human In the Loop MiddleWare
# Pause agent execution for human approval, editing, or rejection of tool calls before they execute. Human-in-the-loop is useful for the following:
# - High-stakes operations requiring human approval (e.g. database writes, financial transactions).
# - Compliance workflows where human oversight is mandatory.
# - Long-running conversations where human feedback guides the agent.

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import HumanInTheLoopMiddleware
from langgraph.checkpoint.memory import InMemorySaver

@tool
def read_email_send(email_id: str) -> str:
    """Function to read an email with ID"""
    return f"Email content for ID: {email_id}"

@tool
def send_email_tool(recipient: str, subject: str, body:str) -> str:
    """Function to send email with email ID"""
    return f"Email send to {recipient} with subject {subject}."

# %%
agent=create_agent(
    model=llm,
    tools=[read_email_tool,send_email_tool],
    checkpointer=InMemorySaver(),
    middleware=[
        HumanInTheLoopMiddleware(
            interrupt_on={
                "send_email_tool":{
                    "allowed_decisions":["approve","edit","reject"]
                },
                "read_email_tool":False,

            }
        )
    ]
)

# %%
config = {"configurable": {"thread_id": "test-approve"}}

result = agent.invoke({'messages': [HumanMessage(content='send email to chandan@gmail.com with subject "Hello brother" and body "what are u doing?"')]},
config=config
)
result
# Out:
# {'messages': [HumanMessage(content='send email to chandan@gmail.com with subject "Hello brother" and body "what are u doing?"', additional_kwargs={}, response_metadata={}, id='5d2a0265-44cc-43cb-9867-c822d5c6f7e7'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '30jnknk05', 'function': {'arguments': '{"body":"what are u doing?","recipient":"chandan@gmail.com","subject":"Hello brother"}', 'name': 'send_email_tool'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 35, 'prompt_tokens': 314, 'total_tokens': 349, 'completion_time': 0.042570706, 'completion_tokens_details': None, 'prompt_time': 0.01934899, 'prompt_tokens_details': None, 'queue_time': 0.048985953, 'total_time': 0.061919696}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c17a7-34f5-7a72-a8f2-454345741f6a-0', tool_calls=[{'name': 'send_email_tool', 'args': {'body': 'what are u doing?', 'recipient': 'chandan@gmail.com', 'subject': 'Hello brother'}, 'id': '30jnknk05', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 314, 'output_tokens': 35, 'total_tokens': 349})],
#  '__interrupt__': [Interrupt(value={'action_requests': [{'name': 'send_email_tool', 'args': {'body': 'what are u doing?', 'recipient': 'chandan@gmail.com', 'subject': 'Hello brother'}, 'description': "Tool execution requires approval\n\nTool: send_email_tool\nArgs: {'body': 'what are u doing?', 'recipient': 'chandan@gmail.com', 'subject': 'Hello brother'}"}], 'review_configs': [{'action_name': 'send_email_tool', 'allowed_decisions': ['approve', 'edit', 'reject']}]}, id='bdc34a48c9c6aef54abe5b9b7e77fc96')]}

# %%
from langgraph.types import Command
# Step 2: Approve
if "__interrupt__" in result:
    print("⏸️ Paused! Approving...")
    
    result = agent.invoke(
        Command(
            resume={
                "decisions": [
                    {"type": "approve"}
                ]
            }
        ),
        config=config
    )
    
    print(f"✅ Result: {result['messages'][-1].content}")
# Out:
# ⏸️ Paused! Approving...
# ✅ Result:

# %% [markdown]
# ### In that AIMessages content is empty so free api key do not provide that try to use openai api key then its active

# %%
result
# Out:
# {'messages': [HumanMessage(content='send email to chandan@gmail.com with subject "Hello brother" and body "what are u doing?"', additional_kwargs={}, response_metadata={}, id='5d2a0265-44cc-43cb-9867-c822d5c6f7e7'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '30jnknk05', 'function': {'arguments': '{"body":"what are u doing?","recipient":"chandan@gmail.com","subject":"Hello brother"}', 'name': 'send_email_tool'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 35, 'prompt_tokens': 314, 'total_tokens': 349, 'completion_time': 0.042570706, 'completion_tokens_details': None, 'prompt_time': 0.01934899, 'prompt_tokens_details': None, 'queue_time': 0.048985953, 'total_time': 0.061919696}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c17a7-34f5-7a72-a8f2-454345741f6a-0', tool_calls=[{'name': 'send_email_tool', 'args': {'body': 'what are u doing?', 'recipient': 'chandan@gmail.com', 'subject': 'Hello brother'}, 'id': '30jnknk05', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 314, 'output_tokens': 35, 'total_tokens': 349}),
#   ToolMessage(content='Email send to chandan@gmail.com with subject Hello brother.', name='send_email_tool', id='714f14b0-38ae-4861-b899-8e30ef6963de', tool_call_id='30jnknk05'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '90esjknw5', 'function': {'arguments': '{"email_id":"12345"}', 'name': 'read_email_tool'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 371, 'total_tokens': 388, 'completion_time': 0.023628372, 'completion_tokens_details': None, 'prompt_time': 0.025882396, 'prompt_tokens_details': None, 'queue_time': 0.054375364, 'total_time': 0.049510768}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c17a7-6389-7d63-8150-eec0497373c8-0', tool_calls=[{'name': 'read_email_tool', 'args': {'email_id': '12345'}, 'id': '90esjknw5', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 371, 'output_tokens': 17, 'total_tokens': 388}),
#   ToolMessage(content='Email content for ID: 12345', name='read_email_tool', id='ccf38b6a-002b-4e66-9d02-5058319a9a0c', tool_call_id='90esjknw5'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '64mzb29t6', 'function': {'arguments': '{"email_id":"67890"}', 'name': 'read_email_tool'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 406, 'total_tokens': 423, 'completion_time': 0.01437301, 'completion_tokens_details': None, 'prompt_time': 0.025516194, 'prompt_tokens_details': None, 'queue_time': 0.053484666, 'total_time': 0.039889204}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c17a7-643f-7842-93a3-24910fd06a16-0', tool_calls=[{'name': 'read_email_tool', 'args': {'email_id': '67890'}, 'id': '64mzb29t6', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 406, 'output_tokens': 17, 'total_tokens': 423}),
#   ToolMessage(content='Email content for ID: 67890', name='read_email_tool', id='56db84c6-4c46-43cb-adfe-c50c0c69ef8e', tool_call_id='64mzb29t6'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'x4f0am045', 'function': {'arguments': '{"body":"I am doing good, thanks for asking","recipient":"chandan@gmail.com","subject":"Re: Hello brother"}', 'name': 'send_email_tool'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 41, 'prompt_tokens': 441, 'total_tokens': 482, 'completion_time': 0.051922486, 'completion_tokens_details': None, 'prompt_time': 0.033149578, 'prompt_tokens_details': None, 'queue_time': 0.054981082, 'total_time': 0.085072064}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c17a7-64d1-7192-a802-2a0a19850040-0', tool_calls=[{'name': 'send_email_tool', 'args': {'body': 'I am doing good, thanks for asking', 'recipient': 'chandan@gmail.com', 'subject': 'Re: Hello brother'}, 'id': 'x4f0am045', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 441, 'output_tokens': 41, 'total_tokens': 482})],
#  '__interrupt__': [Interrupt(value={'action_requests': [{'name': 'send_email_tool', 'args': {'body': 'I am doing good, thanks for asking', 'recipient': 'chandan@gmail.com', 'subject': 'Re: Hello brother'}, 'description': "Tool execution requires approval\n\nTool: send_email_tool\nArgs: {'body': 'I am doing good, thanks for asking', 'recipient': 'chandan@gmail.com', 'subject': 'Re: Hello brother'}"}], 'review_configs': [{'action_name': 'send_email_tool', 'allowed_decisions': ['approve', 'edit', 'reject']}]}, id='a73ee35ceed79045304c829d914a8d6d')]}

# %% [markdown]
# ### Reject

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import HumanInTheLoopMiddleware
from langgraph.checkpoint.memory import InMemorySaver


def read_email_tool(email_id: str) -> str:
    """Mock function to read an email by its ID."""
    return f"Email content for ID: {email_id}"

def send_email_tool(recipient: str, subject: str, body: str) -> str:
    """Mock function to send an email."""
    return f"Email sent to {recipient} with subject '{subject}'"

agent = create_agent(
    model=llm,
    tools=[read_email_tool,send_email_tool],
    checkpointer=InMemorySaver(),
    middleware=[
        HumanInTheLoopMiddleware(
            interrupt_on={
                "send_email_tool": {
                    "allowed_decisions": ["approve", "edit", "reject"],
                },
                "read_email_tool": False,
            }
        ),
    ],
)

# %%
config = {"configurable": {"thread_id": "test-reject"}}
# Step 1: Request
result = agent.invoke(
    {"messages": [HumanMessage(content="Send email to john@test.com with subject 'Hello' and body 'How are you?'")]},
    config=config)

# %%
result
# Out:
# {'messages': [HumanMessage(content="Send email to john@test.com with subject 'Hello' and body 'How are you?'", additional_kwargs={}, response_metadata={}, id='2f3eca1e-26cd-415c-9c25-b11f97e4f88a'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'ffa98yr54', 'function': {'arguments': '{"body":"How are you?","recipient":"john@test.com","subject":"Hello"}', 'name': 'send_email_tool'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 309, 'total_tokens': 341, 'completion_time': 0.028206757, 'completion_tokens_details': None, 'prompt_time': 0.019181513, 'prompt_tokens_details': None, 'queue_time': 0.050278617, 'total_time': 0.04738827}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c17a7-d92c-7ec3-9ec4-a9fa6bc28152-0', tool_calls=[{'name': 'send_email_tool', 'args': {'body': 'How are you?', 'recipient': 'john@test.com', 'subject': 'Hello'}, 'id': 'ffa98yr54', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 309, 'output_tokens': 32, 'total_tokens': 341})],
#  '__interrupt__': [Interrupt(value={'action_requests': [{'name': 'send_email_tool', 'args': {'body': 'How are you?', 'recipient': 'john@test.com', 'subject': 'Hello'}, 'description': "Tool execution requires approval\n\nTool: send_email_tool\nArgs: {'body': 'How are you?', 'recipient': 'john@test.com', 'subject': 'Hello'}"}], 'review_configs': [{'action_name': 'send_email_tool', 'allowed_decisions': ['approve', 'edit', 'reject']}]}, id='aa13870d34ed910cd641c62f6233ee73')]}

# %%
# Step 2: Reject
if "__interrupt__" in result:
    print("⏸️ Paused! Approving...")
    
    result = agent.invoke(
        Command(
            resume={
                "decisions": [
                    {"type": "reject"}
                ]
            }
        ),
        config=config
    )
    
    print(f"✅ Result: {result['messages'][-1].content}")
# Out:
# ⏸️ Paused! Approving...
# ✅ Result:

# %% [markdown]
# ### Editing

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import HumanInTheLoopMiddleware
from langgraph.checkpoint.memory import InMemorySaver


def read_email_tool(email_id: str) -> str:
    """Mock function to read an email by its ID."""
    return f"Email content for ID: {email_id}"

def send_email_tool(recipient: str, subject: str, body: str) -> str:
    """Mock function to send an email."""
    return f"Email sent to {recipient} with subject '{subject}'"

agent = create_agent(
    model=llm,
    tools=[read_email_tool,send_email_tool],
    checkpointer=InMemorySaver(),
    middleware=[
        HumanInTheLoopMiddleware(
            interrupt_on={
                "send_email_tool": {
                    "allowed_decisions": ["approve", "edit", "reject"],
                },
                "read_email_tool": False,
            }
        ),
    ],
)

# %%
config = {"configurable": {"thread_id": "test-edit"}}

# Step 1: Request (with wrong info)
result = agent.invoke(
    {"messages": [HumanMessage(content="Send email to wrong@email.com with subject 'Test' and body 'Hello'")]},
    config=config
)

# %%
result
# Out:
# {'messages': [HumanMessage(content="Send email to wrong@email.com with subject 'Test' and body 'Hello'", additional_kwargs={}, response_metadata={}, id='a575551d-79d9-4da0-ba65-9a2e5f69a942'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'j7wd5z4tf', 'function': {'arguments': '{"body":"Hello","recipient":"wrong@email.com","subject":"Test"}', 'name': 'send_email_tool'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 307, 'total_tokens': 337, 'completion_time': 0.026531862, 'completion_tokens_details': None, 'prompt_time': 0.019788996, 'prompt_tokens_details': None, 'queue_time': 0.053387664, 'total_time': 0.046320858}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c17ad-c3c8-7800-b2e7-fccd49a0c803-0', tool_calls=[{'name': 'send_email_tool', 'args': {'body': 'Hello', 'recipient': 'wrong@email.com', 'subject': 'Test'}, 'id': 'j7wd5z4tf', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 307, 'output_tokens': 30, 'total_tokens': 337})],
#  '__interrupt__': [Interrupt(value={'action_requests': [{'name': 'send_email_tool', 'args': {'body': 'Hello', 'recipient': 'wrong@email.com', 'subject': 'Test'}, 'description': "Tool execution requires approval\n\nTool: send_email_tool\nArgs: {'body': 'Hello', 'recipient': 'wrong@email.com', 'subject': 'Test'}"}], 'review_configs': [{'action_name': 'send_email_tool', 'allowed_decisions': ['approve', 'edit', 'reject']}]}, id='38616eee8fd429ff6f331a574021273a')]}

# %%
# Step 2: Edit and approve
if "__interrupt__" in result:
    print("⏸️ Paused! Editing...")
    
    result = agent.invoke(
        Command(
            resume={
                "decisions": [
                    {
                        "type": "edit",
                        "edited_action": {
                            "name": "send_email_tool",      # Tool name
                            "args": {                   # New arguments
                                "recipient": "correct@email.com",
                                "subject": "Corrected Subject",
                                "body": "This was edited by human before sending"
                            }
                        }
                    }
                ]
            }
        ),
        config=config
    )
    
    print(f"✏️ Result: {result['messages'][-1].content}")
# Out:
# ⏸️ Paused! Editing...
# ✏️ Result:

# %%
result
# Out:
# {'messages': [HumanMessage(content="Send email to wrong@email.com with subject 'Test' and body 'Hello'", additional_kwargs={}, response_metadata={}, id='a575551d-79d9-4da0-ba65-9a2e5f69a942'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'j7wd5z4tf', 'function': {'arguments': '{"body":"Hello","recipient":"wrong@email.com","subject":"Test"}', 'name': 'send_email_tool'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 307, 'total_tokens': 337, 'completion_time': 0.026531862, 'completion_tokens_details': None, 'prompt_time': 0.019788996, 'prompt_tokens_details': None, 'queue_time': 0.053387664, 'total_time': 0.046320858}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c17ad-c3c8-7800-b2e7-fccd49a0c803-0', tool_calls=[{'type': 'tool_call', 'name': 'send_email_tool', 'args': {'recipient': 'correct@email.com', 'subject': 'Corrected Subject', 'body': 'This was edited by human before sending'}, 'id': 'j7wd5z4tf'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 307, 'output_tokens': 30, 'total_tokens': 337}),
#   ToolMessage(content="Email sent to correct@email.com with subject 'Corrected Subject'", name='send_email_tool', id='c9c79db6-5efe-45d9-870b-660095ee556a', tool_call_id='j7wd5z4tf'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'xwq66bh7g', 'function': {'arguments': '{"body":"Hello","recipient":"wrong@email.com","subject":"Test"}', 'name': 'send_email_tool'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 368, 'total_tokens': 398, 'completion_time': 0.022619216, 'completion_tokens_details': None, 'prompt_time': 0.02381014, 'prompt_tokens_details': None, 'queue_time': 0.04908745, 'total_time': 0.046429356}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c17ae-050b-7b12-99c8-0173de18fc90-0', tool_calls=[{'name': 'send_email_tool', 'args': {'body': 'Hello', 'recipient': 'wrong@email.com', 'subject': 'Test'}, 'id': 'xwq66bh7g', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 368, 'output_tokens': 30, 'total_tokens': 398})],
#  '__interrupt__': [Interrupt(value={'action_requests': [{'name': 'send_email_tool', 'args': {'body': 'Hello', 'recipient': 'wrong@email.com', 'subject': 'Test'}, 'description': "Tool execution requires approval\n\nTool: send_email_tool\nArgs: {'body': 'Hello', 'recipient': 'wrong@email.com', 'subject': 'Test'}"}], 'review_configs': [{'action_name': 'send_email_tool', 'allowed_decisions': ['approve', 'edit', 'reject']}]}, id='6e19cbe6f5410da9f9e5dbf54c467c0f')]}
